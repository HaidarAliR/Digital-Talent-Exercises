# %%
import mysql.connector
import pandas as pd

mydb = mysql.connector.connect(
    host='localhost',
    user='root',
    passwd='789AliRizqi456',
    database='classicmodels'
)

def run(sql):
    df = pd.read_sql_query(sql,mydb)
    return df
#List of tables and columns
# run("SHOW TABLES")
# run("SHOW COLUMNS FROM customers")
run("SHOW COLUMNS FROM employees")
# run("SHOW COLUMNS FROM offices")
# run("SHOW COLUMNS FROM orderdetails")
# run("SHOW COLUMNS FROM orders")
# run("SHOW COLUMNS FROM payments")
# run("SHOW COLUMNS FROM productlines")
# run("SHOW COLUMNS FROM products")
# Out:
#             Field          Type Null  Key Default Extra
# 0  employeeNumber       int(11)   NO  PRI    None
# 1        lastName   varchar(50)   NO         None
# 2       firstName   varchar(50)   NO         None
# 3       extension   varchar(10)   NO         None
# 4           email  varchar(100)   NO         None
# 5      officeCode   varchar(10)   NO  MUL    None
# 6       reportsTo       int(11)  YES  MUL    None
# 7        jobTitle   varchar(50)   NO         None

# %%
# NO. 1 Prepare a list of 
# offices sorted by country, state, city.
run("SELECT officeCode,country,state,city FROM offices ORDER BY country,state,city  ")
# Out:
#   officeCode    country       state           city
# 0          6  Australia        None         Sydney
# 1          4     France        None          Paris
# 2          5      Japan  Chiyoda-Ku          Tokyo
# 3          7         UK        None         London
# 4          1        USA          CA  San Francisco
# 5          2        USA          MA         Boston
# 6          3        USA          NY            NYC

# %%
#NO. 2
#how many employees are there in the company?
print(len(run("SELECT employeeNumber FROM employees")))
# Out:
# 23

# %%
#NO. 3
#What is the total of payments received?
print(sum(run("SELECT amount FROM payments").sum()))
# Out:
# 8853839.23

# %%
#NO. 4
#List the product lines that contain 'Cars'
run("""
SELECT
    productLine
FROM
    productlines
WHERE
    productLine LIKE '%Cars%'
    """)
# Out:
#     productLine
# 0  Classic Cars
# 1  Vintage Cars

# %%
#NO. 5
#Report total payments for October 28, 2004.
run("SELECT paymentDate,amount FROM payments WHERE paymentDate='2004-10-28'")
# Out:
#   paymentDate    amount
# 0  2004-10-28  47411.33

# %%
#NO. 6
#Report those payments greater than $100,000
run("""SELECT 
            checkNumber,customerNumber,paymentDate,amount
        FROM
            payments
        WHERE
            amount > 100000
    """)
# Out:
#   checkNumber  customerNumber paymentDate     amount
# 0    AE215433             124  2005-03-05  101244.59
# 1    KI131716             124  2003-08-15  111654.40
# 2     ID10962             141  2004-12-31  116208.40
# 3    JE105477             141  2005-03-18  120166.58
# 4    KM172879             148  2003-12-26  105743.00

# %%
#NO. 7
#List the product in each product line
run("SELECT productName,productLine FROM products ORDER BY productLine")
# Out:
#                                      productName       productLine
# 0                       1952 Alpine Renault 1300      Classic Cars
# 1                            1972 Alfa Romeo GTA      Classic Cars
# 2                         1962 LanciaA Delta 16V      Classic Cars
# 3                              1968 Ford Mustang      Classic Cars
# 4                              2001 Ferrari Enzo      Classic Cars
# 5                             1969 Corvair Monza      Classic Cars
# 6                             1968 Dodge Charger      Classic Cars
# 7                               1969 Ford Falcon      Classic Cars
# 8                        1970 Plymouth Hemi Cuda      Classic Cars
# 9                             1969 Dodge Charger      Classic Cars
# 10                               1993 Mazda RX-7      Classic Cars
# 11                         1965 Aston Martin DB5      Classic Cars
# 12                   1948 Porsche 356-A Roadster      Classic Cars
# ...

# %%
#How many products in each product line?
run("SELECT productLine,COUNT(*) AS JumlahProduk FROM products GROUP BY productLine")
# Out:
#         productLine  JumlahProduk
# 0      Classic Cars            38
# 1       Motorcycles            13
# 2            Planes            12
# 3             Ships             9
# 4            Trains             3
# 5  Trucks and Buses            11
# 6      Vintage Cars            24

# %%
# What is the minimum payment received?
run("SELECT MIN(amount) AS HargaTermurah FROM payments")
# Out:
#    HargaTermurah
# 0         615.45

# %%
# List all payments greater than twice the average payment.
run("""SELECT
            customerNumber,amount
        FROM
            payments
        WHERE
            amount > 2*(SELECT AVG(amount) FROM payments)
        
    """)
# Out:
#     customerNumber     amount
# 0              114   82261.22
# 1              124  101244.59
# 2              124   85410.87
# 3              124   83598.04
# 4              124  111654.40
# 5              141  116208.40
# 6              141   65071.26
# 7              141  120166.58
# 8              148  105743.00
# 9              167   85024.46
# 10             239   80375.24
# 11             321   85559.12
# 12             323   75020.13

# %%
# What is the average 
# percentage markup of the MSRP on buyPrice?

run("""SELECT
            buyPrice/(MSRP-buyPrice)*100 AS MarkUpPercentageAverage
        FROM
            products
    """).mean()
# Out:
# MarkUpPercentageAverage    126.368919
# dtype: float64

# %%
# How many distinct products does ClassicModels sell?
run("""SELECT COUNT(productCode) AS Jumlah_Produk FROM products
        """)
# Out:
#    Jumlah_Produk
# 0            110

# %%
# Report the name and city of customers who don't have sales representatives?
run("""
    SELECT city,customerName
    FROM customers
    WHERE city NOT IN (SELECT city FROM offices)
    """)
# Out:
#                  city                        customerName
# 0              Nantes                   Atelier graphique
# 1           Las Vegas                  Signal Gift Stores
# 2           Melbourne          Australian Collectors, Co.
# 3              Nantes                   La Rochelle Gifts
# 4             Stavern                  Baane Mini Imports
# 5          San Rafael        Mini Gifts Distributors Ltd.
# 6            Warszawa                  Havel & Zbyszek Co
# 7           Frankfurt                Blauer See Auto, Co.
# 8              Madrid              Euro+ Shopping Channel
# 9               Luleå            Volvo Model Replicas, Co
# 10          Kobenhavn            Danish Wholesale Imports
# 11               Lyon              Saveley & Henriot, Co.
# 12          Singapore             Dragon Souveniers, Ltd.
# 13          Allentown               Diecast Classics Inc.
# 14         Burlingame                Technics Stores Inc.
# ...

# %%
# What are the names of executives with VP or Manager 
# in their title? Use the CONCAT function to combine the employee's 
# first name and last name into a single field for reporting.
run("""
    SELECT CONCAT(firstName,' ',lastName) AS fullName, jobTitle
    FROM employees
    WHERE jobTitle LIKE '%Manager%' OR jobTitle LIKE '%VP%'
""")
# Out:
#             fullName              jobTitle
# 0     Mary Patterson              VP Sales
# 1      Jeff Firrelli          VP Marketing
# 2  William Patterson  Sales Manager (APAC)
# 3      Gerard Bondur   Sale Manager (EMEA)
# 4        Anthony Bow    Sales Manager (NA)
